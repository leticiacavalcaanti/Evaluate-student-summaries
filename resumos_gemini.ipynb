# %%
import os
import time
import json
import pandas as pd
from dotenv import load_dotenv
import google.generativeai as genai
import csv

# Load environment variables
load_dotenv()
gemini_api = os.getenv("GEMINI_API_KEY")
if not gemini_api:
    raise ValueError("Chave da API GEMINI_API_KEY não encontrada no arquivo .env.")

# Configure Gemini
genai.configure(api_key=gemini_api)

def extract_json_from_response(response_text):
    """Tenta extrair o JSON da resposta removendo formatação markdown."""
    try:
        clean_text = response_text.strip().replace('```json', '').replace('```', '')
        return json.loads(clean_text)
    except json.JSONDecodeError:
        start = response_text.find('{')
        end = response_text.rfind('}') + 1
        if start != -1 and end != 0:
            return json.loads(response_text[start:end])
        raise

def avaliar_resumo_com_prompt(prompt_text, summary_text):
    """
    Avalia o resumo usando a API do Gemini com retentativas e tratamento de erros.
    """
    max_retries = 3
    for attempt in range(max_retries):
        try:
            full_prompt = (
                f"Consider the following prompt that was given to the students:\n"
                f"{prompt_text}\n\n"
                f"Now, consider the following summary written by the student:\n"
                f"{summary_text}\n\n"
                "Please evaluate the summary based on the task defined in the prompt and return a JSON response "
                "with the keys 'content' and 'wording'. The score for 'content' should reflect the quality of "
                "representing the main idea and details, while the score for 'wording' should reflect the clarity, "
                "accuracy, and fluency of the text. The grades go from 0 to 10.\n"
                "Response MUST be in JSON format only, with no additional text. Example: {{\"content\": 5, \"wording\": 5}}"
            )

            model = genai.GenerativeModel('gemma-3-27b-it')
            response = model.generate_content(
                full_prompt,
                generation_config=genai.types.GenerationConfig(
                    temperature=0,
                    max_output_tokens=200
                )
            )
            
            resposta_texto = response.text.strip()
            notas = extract_json_from_response(resposta_texto)
            
            content = notas.get("content")
            wording = notas.get("wording")
            
            if content is None or wording is None:
                raise ValueError(f"Resposta incompleta: {resposta_texto}")
            if not isinstance(content, (int, float)) or not isinstance(wording, (int, float)):
                raise ValueError(f"Formato numérico inválido: {resposta_texto}")
            
            return float(content), float(wording)
            
        except json.JSONDecodeError as e:
            print(f"Tentativa {attempt + 1}: Erro ao decodificar JSON: {e}")
            print("Resposta recebida:", resposta_texto)
            time.sleep(2 ** attempt)
        except ValueError as e:
            print(f"Tentativa {attempt + 1}: {e}")
            time.sleep(2 ** attempt)
        except Exception as e:
            print(f"Tentativa {attempt + 1}: Erro inesperado: {str(e)}")
            time.sleep(2 ** attempt)
    
    print(f"Falha após {max_retries} tentativas para: {summary_text[:50]}...")
    return None, None

# Ler e processar dados
prompts_test_df = pd.read_csv("prompts_train.csv")
summaries_test_df = pd.read_csv("summaries_train.csv", quoting=csv.QUOTE_MINIMAL)
merged_test_df = summaries_test_df.merge(prompts_test_df, on="prompt_id", how="left")

content_scores = []
wording_scores = []

print("Avaliando todos registros do conjunto de teste (prompt + resumo):")

# Processamento síncrono
for i, row in merged_test_df.iterrows():
    content, wording = avaliar_resumo_com_prompt(row['prompt_text'], row['text'])
    content_scores.append(content)
    wording_scores.append(wording)
    print(f"Processado {i+1}/{len(merged_test_df)} - Content: {content}, Wording: {wording}")
    time.sleep(1)  # Adiciona um delay entre requisições

# Criar DataFrame de submissão
submission = pd.DataFrame({
    'student_id': merged_test_df['student_id'],
    'prompt_id': merged_test_df['prompt_id'],
    'content': content_scores,
    'wording': wording_scores
})

submission.to_csv("submission_test.csv", index=False)
print("\nArquivo submission_test.csv gerado com sucesso!")
# Out:
# Avaliando todos registros do conjunto de teste (prompt + resumo):
# Processado 1/994 - Content: 6.0, Wording: 5.0
# Processado 2/994 - Content: 4.0, Wording: 3.0
# Processado 3/994 - Content: 8.0, Wording: 6.0
# Processado 4/994 - Content: 3.0, Wording: 2.0
# Processado 5/994 - Content: 7.0, Wording: 6.0
# Processado 6/994 - Content: 8.0, Wording: 7.0
# Processado 7/994 - Content: 6.0, Wording: 4.0
# Processado 8/994 - Content: 4.0, Wording: 3.0
# Processado 9/994 - Content: 6.0, Wording: 7.0
# Processado 10/994 - Content: 6.0, Wording: 4.0
# Processado 11/994 - Content: 1.0, Wording: 2.0
# Processado 12/994 - Content: 8.0, Wording: 6.0
# Processado 13/994 - Content: 6.0, Wording: 4.0
# Processado 14/994 - Content: 8.0, Wording: 7.0
# Processado 15/994 - Content: 7.0, Wording: 6.0
# Processado 16/994 - Content: 7.0, Wording: 6.0
# Processado 17/994 - Content: 6.0, Wording: 4.0
# Processado 18/994 - Content: 7.0, Wording: 6.0
# Processado 19/994 - Content: 7.0, Wording: 4.0
# Processado 20/994 - Content: 7.0, Wording: 6.0
# Processado 21/994 - Content: 4.0, Wording: 3.0
# Processado 22/994 - Content: 5.0, Wording: 4.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Falha após 3 tentativas para: Tragedy much b complex, Tragedy much b complex, t ...
# Processado 23/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Falha após 3 tentativas para: Since it was the custom, whenever meat was so spoi...
# Processado 24/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# Falha após 3 tentativas para:    First on the pyramid were the Pharaohs. The pha...
# Processado 25/994 - Content: None, Wording: None
# Processado 26/994 - Content: 6.0, Wording: 9.0
# Processado 27/994 - Content: 6.0, Wording: 8.0
# Processado 28/994 - Content: 4.0, Wording: 3.0
# Processado 29/994 - Content: 8.0, Wording: 6.0
# Processado 30/994 - Content: 7.0, Wording: 6.0
# Processado 31/994 - Content: 8.0, Wording: 9.0
# Processado 32/994 - Content: 6.0, Wording: 4.0
# Processado 33/994 - Content: 8.0, Wording: 7.0
# Processado 34/994 - Content: 6.0, Wording: 4.0
# Processado 35/994 - Content: 7.0, Wording: 4.0
# Processado 36/994 - Content: 3.0, Wording: 4.0
# Processado 37/994 - Content: 6.0, Wording: 4.0
# Processado 38/994 - Content: 7.0, Wording: 4.0
# Processado 39/994 - Content: 7.0, Wording: 6.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 51
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 49
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Falha após 3 tentativas para: The Thrid Wave movement in the school has more stu...
# Processado 40/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# Falha após 3 tentativas para: In the second paragraph Aritole explained, "A perf...
# Processado 41/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# Processado 42/994 - Content: 6.0, Wording: 5.0
# Processado 43/994 - Content: 7.0, Wording: 4.0
# Processado 44/994 - Content: 3.0, Wording: 6.0
# Processado 45/994 - Content: 6.0, Wording: 7.0
# Processado 46/994 - Content: 6.0, Wording: 5.0
# Processado 47/994 - Content: 3.0, Wording: 6.0
# Processado 48/994 - Content: 8.0, Wording: 7.0
# Processado 49/994 - Content: 7.0, Wording: 4.0
# Processado 50/994 - Content: 4.0, Wording: 3.0
# Processado 51/994 - Content: 6.0, Wording: 7.0
# Processado 52/994 - Content: 3.0, Wording: 6.0
# Processado 53/994 - Content: 6.0, Wording: 4.0
# Processado 54/994 - Content: 7.0, Wording: 8.0
# Processado 55/994 - Content: 8.0, Wording: 7.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 51
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Falha após 3 tentativas para: The structure of the ancient Egyptian system of go...
# Processado 56/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Falha após 3 tentativas para: in egyptian systems they always had people with th...
# Processado 57/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# Processado 58/994 - Content: 3.0, Wording: 2.0
# Processado 59/994 - Content: 9.0, Wording: 8.0
# Processado 60/994 - Content: 4.0, Wording: 3.0
# Processado 61/994 - Content: 6.0, Wording: 4.0
# Processado 62/994 - Content: 3.0, Wording: 2.0
# Processado 63/994 - Content: 8.0, Wording: 6.0
# Processado 64/994 - Content: 7.0, Wording: 6.0
# Processado 65/994 - Content: 6.0, Wording: 7.0
# Processado 66/994 - Content: 6.0, Wording: 7.0
# Processado 67/994 - Content: 6.0, Wording: 4.0
# Processado 68/994 - Content: 6.0, Wording: 4.0
# Processado 69/994 - Content: 8.0, Wording: 6.0
# Processado 70/994 - Content: 6.0, Wording: 4.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Falha após 3 tentativas para: Three elements of an ideal tragedy as described by...
# Processado 71/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Falha após 3 tentativas para: Famers worked for the pharaohs by selling about 60...
# Processado 72/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# Falha após 3 tentativas para: Aristotle begins to explain what in his eyes is th...
# Processado 73/994 - Content: None, Wording: None
# Processado 74/994 - Content: 8.0, Wording: 7.0
# Processado 75/994 - Content: 8.0, Wording: 9.0
# Processado 76/994 - Content: 2.0, Wording: 3.0
# Processado 77/994 - Content: 6.0, Wording: 4.0
# Processado 78/994 - Content: 6.0, Wording: 5.0
# Processado 79/994 - Content: 8.0, Wording: 7.0
# Processado 80/994 - Content: 7.0, Wording: 6.0
# Processado 81/994 - Content: 7.0, Wording: 6.0
# Processado 82/994 - Content: 7.0, Wording: 8.0
# Processado 83/994 - Content: 6.0, Wording: 3.0
# Processado 84/994 - Content: 7.0, Wording: 4.0
# Processado 85/994 - Content: 7.0, Wording: 6.0
# Processado 86/994 - Content: 6.0, Wording: 4.0
# Processado 87/994 - Content: 7.0, Wording: 6.0
# Processado 88/994 - Content: 6.0, Wording: 4.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 49
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Falha após 3 tentativas para: An ideal tragedy should feature a man who is neith...
# Processado 89/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Falha após 3 tentativas para: Factories would rub chemicals like soda and pickle...
# Processado 90/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# Processado 91/994 - Content: 8.0, Wording: 6.0
# Processado 92/994 - Content: 4.0, Wording: 3.0
# Processado 93/994 - Content: 4.0, Wording: 3.0
# Processado 94/994 - Content: 6.0, Wording: 5.0
# Processado 95/994 - Content: 7.0, Wording: 4.0
# Processado 96/994 - Content: 6.0, Wording: 4.0
# Processado 97/994 - Content: 2.0, Wording: 6.0
# Processado 98/994 - Content: 4.0, Wording: 3.0
# Processado 99/994 - Content: 7.0, Wording: 6.0
# Processado 100/994 - Content: 6.0, Wording: 7.0
# Processado 101/994 - Content: 6.0, Wording: 4.0
# Processado 102/994 - Content: 7.0, Wording: 6.0
# Processado 103/994 - Content: 4.0, Wording: 6.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 59
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 57
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Falha após 3 tentativas para: According to Aristotle, there are three elements o...
# Processado 104/994 - Content: None, Wording: None
# Processado 105/994 - Content: 6.0, Wording: 5.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Falha após 3 tentativas para: 1. The kind of tragedy which some place first, and...
# Processado 106/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Falha após 3 tentativas para: The reading says that the smell was so hard to han...
# Processado 107/994 - Content: None, Wording: None
# Processado 108/994 - Content: 7.0, Wording: 6.0
# Processado 109/994 - Content: 7.0, Wording: 6.0
# Processado 110/994 - Content: 4.0, Wording: 6.0
# Processado 111/994 - Content: 6.0, Wording: 5.0
# Processado 112/994 - Content: 4.0, Wording: 3.0
# Processado 113/994 - Content: 8.0, Wording: 6.0
# Processado 114/994 - Content: 2.0, Wording: 1.0
# Processado 115/994 - Content: 7.0, Wording: 8.0
# Processado 116/994 - Content: 7.0, Wording: 4.0
# Processado 117/994 - Content: 7.0, Wording: 8.0
# Processado 118/994 - Content: 6.0, Wording: 7.0
# Processado 119/994 - Content: 3.0, Wording: 4.0
# Processado 120/994 - Content: 7.0, Wording: 8.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Falha após 3 tentativas para: In paragraph two, it says they would pump hams wit...
# Processado 121/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Falha após 3 tentativas para: The meat packing industry would commonly just mix ...
# Processado 122/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Falha após 3 tentativas para: The Third Wave was developed by Jones who proceede...
# Processado 123/994 - Content: None, Wording: None
# Processado 124/994 - Content: 6.0, Wording: 3.0
# Processado 125/994 - Content: 7.0, Wording: 6.0
# Processado 126/994 - Content: 7.0, Wording: 8.0
# Processado 127/994 - Content: 4.0, Wording: 3.0
# Processado 128/994 - Content: 8.0, Wording: 6.0
# Processado 129/994 - Content: 6.0, Wording: 5.0
# Processado 130/994 - Content: 3.0, Wording: 2.0
# Processado 131/994 - Content: 6.0, Wording: 4.0
# Processado 132/994 - Content: 6.0, Wording: 7.0
# Processado 133/994 - Content: 7.0, Wording: 6.0
# Processado 134/994 - Content: 8.0, Wording: 7.0
# Processado 135/994 - Content: 8.0, Wording: 6.0
# Processado 136/994 - Content: 7.0, Wording: 4.0
# Processado 137/994 - Content: 6.0, Wording: 4.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Falha após 3 tentativas para: The factory would use chemicals to cover up spoile...
# Processado 138/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Falha após 3 tentativas para: Meat packing industrees had many ways to get custo...
# Processado 139/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# Falha após 3 tentativas para:      The Third Wave devoped over such a short time...
# Processado 140/994 - Content: None, Wording: None
# Processado 141/994 - Content: 7.0, Wording: 6.0
# Processado 142/994 - Content: 6.0, Wording: 7.0
# Processado 143/994 - Content: 8.0, Wording: 9.0
# Processado 144/994 - Content: 6.0, Wording: 7.0
# Processado 145/994 - Content: 6.0, Wording: 4.0
# Processado 146/994 - Content: 6.0, Wording: 4.0
# Processado 147/994 - Content: 8.0, Wording: 7.0
# Processado 148/994 - Content: 4.0, Wording: 7.0
# Processado 149/994 - Content: 6.0, Wording: 8.0
# Processado 150/994 - Content: 6.0, Wording: 4.0
# Processado 151/994 - Content: 4.0, Wording: 3.0
# Processado 152/994 - Content: 6.0, Wording: 5.0
# Processado 153/994 - Content: 6.0, Wording: 5.0
# Processado 154/994 - Content: 6.0, Wording: 4.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 51
# }
# ]
# Falha após 3 tentativas para: different social Egyptian systems of government by...
# Processado 155/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Falha após 3 tentativas para: Different social classes invloved in this governme...
# Processado 156/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# Falha após 3 tentativas para: According to the text factories used spoiled meat ...
# Processado 157/994 - Content: None, Wording: None
# Processado 158/994 - Content: 6.0, Wording: 8.0
# Processado 159/994 - Content: 6.0, Wording: 4.0
# Processado 160/994 - Content: 4.0, Wording: 3.0
# Processado 161/994 - Content: 6.0, Wording: 8.0
# Processado 162/994 - Content: 6.0, Wording: 4.0
# Processado 163/994 - Content: 7.0, Wording: 6.0
# Processado 164/994 - Content: 3.0, Wording: 4.0
# Processado 165/994 - Content: 6.0, Wording: 4.0
# Processado 166/994 - Content: 6.0, Wording: 5.0
# Processado 167/994 - Content: 3.0, Wording: 7.0
# Processado 168/994 - Content: 7.0, Wording: 6.0
# Processado 169/994 - Content: 6.0, Wording: 4.0
# Processado 170/994 - Content: 7.0, Wording: 6.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 51
# }
# ]
# Falha após 3 tentativas para: The industry would mix spoiled meat with fresh mea...
# Processado 171/994 - Content: None, Wording: None
# Processado 172/994 - Content: 3.0, Wording: 6.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# Falha após 3 tentativas para: The people out of the third wave felt like they ha...
# Processado 173/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# Falha após 3 tentativas para: For nothing can be more alien to the spirit of Tra...
# Processado 174/994 - Content: None, Wording: None
# Processado 175/994 - Content: 6.0, Wording: 5.0
# Processado 176/994 - Content: 8.0, Wording: 6.0
# Processado 177/994 - Content: 6.0, Wording: 4.0
# Processado 178/994 - Content: 7.0, Wording: 6.0
# Processado 179/994 - Content: 7.0, Wording: 6.0
# Processado 180/994 - Content: 8.0, Wording: 7.0
# Processado 181/994 - Content: 4.0, Wording: 3.0
# Processado 182/994 - Content: 7.0, Wording: 6.0
# Processado 183/994 - Content: 8.0, Wording: 6.0
# Processado 184/994 - Content: 2.0, Wording: 3.0
# Processado 185/994 - Content: 8.0, Wording: 6.0
# Processado 186/994 - Content: 6.0, Wording: 4.0
# Processado 187/994 - Content: 8.0, Wording: 7.0
# Processado 188/994 - Content: 6.0, Wording: 4.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 49
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Falha após 3 tentativas para: The 3 elements of a tragedy are mocking the action...
# Processado 189/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# Falha após 3 tentativas para: the farmers and slaves are at the bottom  the farm...
# Processado 190/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# Processado 191/994 - Content: 8.0, Wording: 7.0
# Processado 192/994 - Content: 6.0, Wording: 4.0
# Processado 193/994 - Content: 7.0, Wording: 6.0
# Processado 194/994 - Content: 2.0, Wording: 3.0
# Processado 195/994 - Content: 8.0, Wording: 7.0
# Processado 196/994 - Content: 7.0, Wording: 6.0
# Processado 197/994 - Content: 6.0, Wording: 7.0
# Processado 198/994 - Content: 6.0, Wording: 4.0
# Processado 199/994 - Content: 6.0, Wording: 4.0
# Processado 200/994 - Content: 7.0, Wording: 6.0
# Processado 201/994 - Content: 6.0, Wording: 3.0
# Processado 202/994 - Content: 3.0, Wording: 6.0
# Processado 203/994 - Content: 4.0, Wording: 3.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# ...
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
# Falha após 3 tentativas para: The facotry would take spoiled meet and can it to ...
# Processado 930/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 51
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Falha após 3 tentativas para: The top of the pyramid is the pharaohs which they ...
# Processado 931/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Falha após 3 tentativas para: The Egyptian society/system of government is "like...
# Processado 932/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# Processado 933/994 - Content: 8.0, Wording: 7.0
# Processado 934/994 - Content: 4.0, Wording: 3.0
# Processado 935/994 - Content: 6.0, Wording: 4.0
# Processado 936/994 - Content: 7.0, Wording: 6.0
# Processado 937/994 - Content: 4.0, Wording: 3.0
# Processado 938/994 - Content: 7.0, Wording: 6.0
# Processado 939/994 - Content: 4.0, Wording: 7.0
# Processado 940/994 - Content: 8.0, Wording: 9.0
# Processado 941/994 - Content: 4.0, Wording: 3.0
# Processado 942/994 - Content: 3.0, Wording: 2.0
# Processado 943/994 - Content: 7.0, Wording: 4.0
# Processado 944/994 - Content: 7.0, Wording: 6.0
# Processado 945/994 - Content: 6.0, Wording: 5.0
# Processado 946/994 - Content: 8.0, Wording: 7.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 49
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Falha após 3 tentativas para: One element of an ideal tragedy is that it should ...
# Processado 947/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Falha após 3 tentativas para: A proper tragedy includes a character who is neith...
# Processado 948/994 - Content: None, Wording: None
# Processado 949/994 - Content: 7.0, Wording: 6.0
# Processado 950/994 - Content: 7.0, Wording: 6.0
# Processado 951/994 - Content: 7.0, Wording: 6.0
# Processado 952/994 - Content: 6.0, Wording: 5.0
# Processado 953/994 - Content: 3.0, Wording: 7.0
# Processado 954/994 - Content: 4.0, Wording: 3.0
# Processado 955/994 - Content: 7.0, Wording: 4.0
# Processado 956/994 - Content: 6.0, Wording: 4.0
# Processado 957/994 - Content: 8.0, Wording: 6.0
# Processado 958/994 - Content: 6.0, Wording: 4.0
# Processado 959/994 - Content: 7.0, Wording: 6.0
# Processado 960/994 - Content: 8.0, Wording: 7.0
# Processado 961/994 - Content: 6.0, Wording: 4.0
# Processado 962/994 - Content: 6.0, Wording: 4.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 51
# }
# ]
# Falha após 3 tentativas para: According to Aristotle, the three main elements of...
# Processado 963/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Falha após 3 tentativas para: The social structure of ancient Egypt was built li...
# Processado 964/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# Falha após 3 tentativas para: Three elements that would create an ideal tragedy ...
# Processado 965/994 - Content: None, Wording: None
# Processado 966/994 - Content: 6.0, Wording: 7.0
# Processado 967/994 - Content: 7.0, Wording: 4.0
# Processado 968/994 - Content: 7.0, Wording: 6.0
# Processado 969/994 - Content: 6.0, Wording: 4.0
# Processado 970/994 - Content: 8.0, Wording: 6.0
# Processado 971/994 - Content: 8.0, Wording: 6.0
# Processado 972/994 - Content: 3.0, Wording: 2.0
# Processado 973/994 - Content: 7.0, Wording: 6.0
# Processado 974/994 - Content: 4.0, Wording: 3.0
# Processado 975/994 - Content: 6.0, Wording: 7.0
# Processado 976/994 - Content: 4.0, Wording: 3.0
# Processado 977/994 - Content: 2.0, Wording: 3.0
# Processado 978/994 - Content: 6.0, Wording: 4.0
# Processado 979/994 - Content: 8.0, Wording: 7.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 49
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Falha após 3 tentativas para: In paragraph 2 the author claims, the factory work...
# Processado 980/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Tentativa 2: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Tentativa 3: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Falha após 3 tentativas para: the ancient egyptian structure system of the gover...
# Processado 981/994 - Content: None, Wording: None
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# Processado 982/994 - Content: 8.0, Wording: 7.0
# Tentativa 1: Erro inesperado: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# Processado 983/994 - Content: 3.0, Wording: 6.0
# Processado 984/994 - Content: 9.0, Wording: 8.0
# Processado 985/994 - Content: 4.0, Wording: 3.0
# Processado 986/994 - Content: 7.0, Wording: 6.0
# Processado 987/994 - Content: 6.0, Wording: 4.0
# Processado 988/994 - Content: 4.0, Wording: 3.0
# Processado 989/994 - Content: 6.0, Wording: 4.0
# Processado 990/994 - Content: 3.0, Wording: 2.0
# Processado 991/994 - Content: 7.0, Wording: 6.0
# Processado 992/994 - Content: 7.0, Wording: 6.0
# Processado 993/994 - Content: 6.0, Wording: 4.0
# Processado 994/994 - Content: 7.0, Wording: 6.0
#
# Arquivo submission_test.csv gerado com sucesso!

# %%
import pprint
for model in genai.list_models():
    pprint.pprint(model)
# Out:
# Model(name='models/chat-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 Chat (Legacy)',
#       description='A legacy text-only model optimized for chat conversations',
#       input_token_limit=4096,
#       output_token_limit=1024,
#       supported_generation_methods=['generateMessage', 'countMessageTokens'],
#       temperature=0.25,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/text-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 (Legacy)',
#       description='A legacy model that understands text and generates text as an output',
#       input_token_limit=8196,
#       output_token_limit=1024,
#       supported_generation_methods=['generateText', 'countTextTokens', 'createTunedTextModel'],
#       temperature=0.7,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/embedding-gecko-001',
#       base_model_id='',
#       version='001',
#       display_name='Embedding Gecko',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=1024,
#       output_token_limit=1,
#       supported_generation_methods=['embedText', 'countTextTokens'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/gemini-1.0-pro-vision-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.0 Pro Vision',
#       description=('The original Gemini 1.0 Pro Vision model version which was optimized for '
#                    'image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. '
#                    'Move to a newer Gemini version.'),
#       input_token_limit=12288,
#       output_token_limit=4096,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.4,
#       max_temperature=None,
#       top_p=1.0,
#       top_k=32)
# Model(name='models/gemini-pro-vision',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.0 Pro Vision',
#       description=('The original Gemini 1.0 Pro Vision model version which was optimized for '
#                    'image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. '
#                    'Move to a newer Gemini version.'),
#       input_token_limit=12288,
#       output_token_limit=4096,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.4,
#       max_temperature=None,
#       top_p=1.0,
#       top_k=32)
# Model(name='models/gemini-1.5-pro-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Pro Latest',
#       description=('Alias that points to the most recent production (non-experimental) release '
#                    'of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 '
#                    'million tokens.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-pro-001',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Pro 001',
#       description=('Stable version of Gemini 1.5 Pro, our mid-size multimodal model that '
#                    'supports up to 2 million tokens, released in May of 2024.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-1.5-pro-002',
#       base_model_id='',
#       version='002',
#       display_name='Gemini 1.5 Pro 002',
#       description=('Stable version of Gemini 1.5 Pro, our mid-size multimodal model that '
#                    'supports up to 2 million tokens, released in September of 2024.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-pro',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Pro',
#       description=('Stable version of Gemini 1.5 Pro, our mid-size multimodal model that '
#                    'supports up to 2 million tokens, released in May of 2024.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash Latest',
#       description=('Alias that points to the most recent production (non-experimental) release '
#                    'of Gemini 1.5 Flash, our fast and versatile multimodal model for scaling '
#                    'across diverse tasks.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-001',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 001',
#       description=('Stable version of Gemini 1.5 Flash, our fast and versatile multimodal model '
#                    'for scaling across diverse tasks, released in May of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-1.5-flash-001-tuning',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 001 Tuning',
#       description=('Version of Gemini 1.5 Flash that supports tuning, our fast and versatile '
#                    'multimodal model for scaling across diverse tasks, released in May of 2024.'),
#       input_token_limit=16384,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createTunedModel'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-1.5-flash',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash',
#       description=('Alias that points to the most recent stable version of Gemini 1.5 Flash, our '
#                    'fast and versatile multimodal model for scaling across diverse tasks.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-002',
#       base_model_id='',
#       version='002',
#       display_name='Gemini 1.5 Flash 002',
#       description=('Stable version of Gemini 1.5 Flash, our fast and versatile multimodal model '
#                    'for scaling across diverse tasks, released in September of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash-8B',
#       description=('Stable version of Gemini 1.5 Flash-8B, our smallest and most cost effective '
#                    'Flash model, released in October of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['createCachedContent', 'generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-001',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash-8B 001',
#       description=('Stable version of Gemini 1.5 Flash-8B, our smallest and most cost effective '
#                    'Flash model, released in October of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['createCachedContent', 'generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash-8B Latest',
#       description=('Alias that points to the most recent production (non-experimental) release '
#                    'of Gemini 1.5 Flash-8B, our smallest and most cost effective Flash model, '
#                    'released in October of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['createCachedContent', 'generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-exp-0827',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 8B Experimental 0827',
#       description=('Experimental release (August 27th, 2024) of Gemini 1.5 Flash-8B, our '
#                    'smallest and most cost effective Flash model. Replaced by '
#                    'Gemini-1.5-flash-8b-001 (stable).'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-exp-0924',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 8B Experimental 0924',
#       description=('Experimental release (September 24th, 2024) of Gemini 1.5 Flash-8B, our '
#                    'smallest and most cost effective Flash model. Replaced by '
#                    'Gemini-1.5-flash-8b-001 (stable).'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.5-pro-exp-03-25',
#       base_model_id='',
#       version='2.5-exp-03-25',
#       display_name='Gemini 2.5 Pro Experimental 03-25',
#       description='Experimental release (March 25th, 2025) of Gemini 2.5 Pro',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-flash-exp',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash Experimental',
#       description='Gemini 2.0 Flash Experimental',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'bidiGenerateContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash',
#       description='Gemini 2.0 Flash',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-001',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash 001',
#       description=('Stable version of Gemini 2.0 Flash, our fast and versatile multimodal model '
#                    'for scaling across diverse tasks, released in January of 2025.'),
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-exp-image-generation',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash (Image Generation) Experimental',
#       description='Gemini 2.0 Flash (Image Generation) Experimental',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'bidiGenerateContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite-001',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash-Lite 001',
#       description='Stable version of Gemini 2.0 Flash Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash-Lite',
#       description='Gemini 2.0 Flash-Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite-preview-02-05',
#       base_model_id='',
#       version='preview-02-05',
#       display_name='Gemini 2.0 Flash-Lite Preview 02-05',
#       description='Preview release (February 5th, 2025) of Gemini 2.0 Flash Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite-preview',
#       base_model_id='',
#       version='preview-02-05',
#       display_name='Gemini 2.0 Flash-Lite Preview',
#       description='Preview release (February 5th, 2025) of Gemini 2.0 Flash Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-pro-exp',
#       base_model_id='',
#       version='2.5-exp-03-25',
#       display_name='Gemini 2.0 Pro Experimental',
#       description='Experimental release (March 25th, 2025) of Gemini 2.5 Pro',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-pro-exp-02-05',
#       base_model_id='',
#       version='2.5-exp-03-25',
#       display_name='Gemini 2.0 Pro Experimental 02-05',
#       description='Experimental release (March 25th, 2025) of Gemini 2.5 Pro',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-exp-1206',
#       base_model_id='',
#       version='2.5-exp-03-25',
#       display_name='Gemini Experimental 1206',
#       description='Experimental release (March 25th, 2025) of Gemini 2.5 Pro',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-flash-thinking-exp-01-21',
#       base_model_id='',
#       version='2.0-exp-01-21',
#       display_name='Gemini 2.0 Flash Thinking Experimental 01-21',
#       description='Experimental release (January 21st, 2025) of Gemini 2.0 Flash Thinking',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.7,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-flash-thinking-exp',
#       base_model_id='',
#       version='2.0-exp-01-21',
#       display_name='Gemini 2.0 Flash Thinking Experimental 01-21',
#       description='Experimental release (January 21st, 2025) of Gemini 2.0 Flash Thinking',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.7,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-flash-thinking-exp-1219',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash Thinking Experimental',
#       description='Gemini 2.0 Flash Thinking Experimental',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.7,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/learnlm-1.5-pro-experimental',
#       base_model_id='',
#       version='001',
#       display_name='LearnLM 1.5 Pro Experimental',
#       description=('Alias that points to the most recent stable version of Gemini 1.5 Pro, our '
#                    'mid-size multimodal model that supports up to 2 million tokens.'),
#       input_token_limit=32767,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemma-3-4b-it',
#       base_model_id='',
#       version='001',
#       display_name='Gemma 3 4B',
#       description='',
#       input_token_limit=32768,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemma-3-12b-it',
#       base_model_id='',
#       version='001',
#       display_name='Gemma 3 12B',
#       description='',
#       input_token_limit=32768,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemma-3-27b-it',
#       base_model_id='',
#       version='001',
#       display_name='Gemma 3 27B',
#       description='',
#       input_token_limit=131072,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/embedding-001',
#       base_model_id='',
#       version='001',
#       display_name='Embedding 001',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=2048,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/text-embedding-004',
#       base_model_id='',
#       version='004',
#       display_name='Text Embedding 004',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=2048,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/gemini-embedding-exp-03-07',
#       base_model_id='',
#       version='exp-03-07',
#       display_name='Gemini Embedding Experimental 03-07',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=8192,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/gemini-embedding-exp',
#       base_model_id='',
#       version='exp-03-07',
#       display_name='Gemini Embedding Experimental',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=8192,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/aqa',
#       base_model_id='',
#       version='001',
#       display_name='Model that performs Attributed Question Answering.',
#       description=('Model trained to return answers to questions that are grounded in provided '
#                    'sources, along with estimating answerable probability.'),
#       input_token_limit=7168,
#       output_token_limit=1024,
#       supported_generation_methods=['generateAnswer'],
#       temperature=0.2,
#       max_temperature=None,
#       top_p=1.0,
#       top_k=40)
# Model(name='models/imagen-3.0-generate-002',
#       base_model_id='',
#       version='002',
#       display_name='Imagen 3.0 002 model',
#       description='Vertex served Imagen 3.0 002 model',
#       input_token_limit=480,
#       output_token_limit=8192,
#       supported_generation_methods=['predict'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
